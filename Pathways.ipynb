# %% [markdown]
# # Visual Representations Of How to Use the Tool As a Writer

# %% [markdown]
# Using the interface should be simple for any writer, and the steps will be displayed below with an example interaction!

# %% [markdown]
# **Step One**
#
# Open the provided link to the website, and enter the necessary information into the slots visualized below.
#
# - In this case, the article we are using is "'Just Shattered': Penn Lightweight Rowing Accused of Racism, Prompting Controversial University Response". The title, content, and department "quaker nation" are provided. In this case this article is already published, but in the future this program will be used by people looking to reviewing unpublished articles.
# - The first question I will ask is: "Can you provide me with SEO key words, a title, and social media construction that can best help boost the outreach of this article based on your data?"

# %%
from IPython.display import Image

# Display the image
Image('images/Image1.png')

# %% [markdown]
# **Step Two**
#
# - Take and asses results:
#
# **Results:**
#
# Based on the article's content, I suggest the following SEO keywords:
#
# Keywords: racism, verbal abuse, rowing team, Penn Athletics, diversity, equity, inclusion, restorative practices
# Long-tail keywords: "racist remarks in college rowing", "verbal abuse on university athletic teams", "Penn Athletics' handling of racial incidents"
# Synonyms: hate speech, discriminatory behavior, microaggressions
# For the title options:
#
# Option 1: "Racism and Verbal Abuse Plague Penn Rowing Team"
#
# Option 2: "Athletic Department Faces Criticism for Handling of Racial Incidents"
#
# Option 3: "Penn Rowing Team Embroiled in Controversy Over Racist Remarks"
#
# Social media construction:
#
# Facebook: "Racism and verbal abuse have no place in college athletics. Read the shocking story of how Penn Athletics handled racial incidents on their rowing team [link to article] #NotInOurHouse #DiversityMatters"
#
# Twitter: "Racism and verbal abuse plague Penn Rowing Team! Read the full story and learn about the school's response: [link to article] #PennAthletics #RacialIncidents"
#
# Instagram: "Athletic departments have a responsibility to create an inclusive environment for all athletes. Unfortunately, this didn't happen for a Penn Rowing team member who faced racism and verbal abuse. Read the full story to learn more about the incident and how it was handled: [link to article] #InclusionMatters #PennAthletics"
#
# Please note that these are just suggestions, and you should adjust them according to your audience and brand tone.

# %% [markdown]
# **Assessment**
#
# These results, based on provided vectors, will provide a boost to the SOE of the article. On top of that, the social meda posts have been designed off of the DP's precedent to boost engagement. Overall, great responses which can boost the article.

# %% [markdown]
# **Step Three**
#
# Next is to do a follow up prompt, to double check your work: "Furthermore, is the article provided inline with the DP style guide? Also, what suggestions for social media can you suggest based on the Daily Pennsylvanians data"
#
# **Results:**
#
# Compliance with DP Style Guide: The article appears to be written in a clear and concise manner, with proper formatting and grammar. The use of quotes from sources adds depth and credibility to the story. However, there are some areas where the article could improve:
#
# - The article does not have a clear headline or title that accurately summarizes the content.
# - Some of the paragraphs are quite long and could be broken up for easier reading.
# - There is no summary or abstract at the beginning of the article.
#
# Suggestions for Social Media: Based on the article's content, here are some suggestions for social media posts:
#
# Headline: "Racism and Verbal Abuse Alleged in Penn Lightweight Rowing Team" - This headline accurately summarizes the article's content.
# Facebook Post: "New report alleges racism and verbal abuse within the Penn lightweight rowing team. Read the full story to learn more about the allegations and how they have affected the victims. #PennLightweightRowing #RacismAllegations"
# Twitter Thread: Thread 1: New report alleges racism & verbal abuse within @Penn lightweight rowing team. Read the full story [link] #PennLightweightRowing #RacismAllegations Thread 2: "The alleged perpetrator has not received just punishment for their actions, while victims have endured emotional toll." [link] #PennLightweightRowing #JusticeForVictims
# Instagram Post: "Read the full story on racism and verbal abuse allegations within the Penn lightweight rowing team [link]. Share your thoughts and concerns in the comments below. #PennLightweightRowing #RacismAllegations"
# Additional Suggestions:
#
# Utilize relevant hashtags, such as #RowingCommunity, #CollegeLife, and #DiversityAndInclusion.
# Encourage readers to share their own experiences or thoughts on the topic in the comments section.
# Consider creating a Facebook event or group discussion around this article's topic.
# Reach out to other student organizations, particularly those focused on diversity and inclusion, to collaborate on sharing this story.
# Important Reminders:
#
# Always prioritize accuracy and fairness when reporting news stories.
# Respect the privacy of individuals involved in the story by avoiding direct identification or harassment.
# Encourage readers to engage in respectful and constructive discussions around the topic.
#
# **Assessment**
#
# These results once again highlight the upside that a R.A.G. powered A.I. can provide. The critiques at the beginning are fully true, but aren't super valuable. There is no headline because the headline is provided in another slot, there is no summary/abstract because that isn't always required, and some paragraphs are quite long. This critiques are accurate, but upon assessment aren't valuable. This is expected of an article as polished as this one since it has already been reviewed and published.
#
# For the social media formatting, the A.I. suggests formats that have been most successful for the DP. This involves hashtags, threads, and concise titles. All of these suggestions can be trusted to positively impact our social media engagement.

# %% [markdown]
# **Step Four** (final step)
#
# Next you have to apply the information given to the applicable sources. Specifically:
# - SEO key words should be plugged into CEO (DP publishing website) under the section "Slug" to help boost interactivity
# - Social Media Headlines should be sent to the proper channels, or written/posted by the writer when they use programs like Later (social media organizer)
# - The suggestions should be reviewed and then published in each respective format
#
# The photos below show CEO, slack stream for instagram, and later. These are the exact websites and processes that would directly benefit from our A.I.

# %%
from IPython.display import Image

# Display the image
Image('image2.png')

# %%
from IPython.display import Image

# Display the image
Image('image3.png')

# %%
from IPython.display import Image

# Display the image
Image('image4.png')
